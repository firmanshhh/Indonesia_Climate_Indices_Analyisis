# %%
import pandas as pd

# %%
data = pd.read_csv('/mnt/dataset/02_REPO_GITHUB_FIRMAN/Developing_Climate_Change_Indices_Station_Dataset/02.output/01.indices/1981_2025/FKLIM_AGGREGATE_1981-01-01_2025-12-31_DAILY.csv')
# Out:
# /tmp/ipykernel_2530171/3211248872.py:1: DtypeWarning: Columns (15,19,23,27) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('/mnt/dataset/02_REPO_GITHUB_FIRMAN/Developing_Climate_Change_Indices_Station_Dataset/02.output/01.indices/1981_2025/FKLIM_AGGREGATE_1981-01-01_2025-12-31_DAILY.csv')

# %%
data[['RAINFALL_24H_MM', 'TEMPERATURE_AVG_C',
       'TEMP_24H_TN_C', 'TEMP_24H_TX_C']].describe()
# Out:
#        RAINFALL_24H_MM  TEMPERATURE_AVG_C  TEMP_24H_TN_C  TEMP_24H_TX_C
# count     1.311731e+06       1.165868e+06   1.245820e+06   1.231929e+06
# mean      7.138202e+00       2.676881e+01   2.307103e+01   3.160049e+01
# std       1.599079e+01       1.603999e+00   1.849591e+00   1.881020e+00
# min       0.000000e+00       1.719396e+01   1.070936e+01   1.965333e+01
# 25%       0.000000e+00       2.600000e+01   2.221995e+01   3.056492e+01
# 50%       0.000000e+00       2.690862e+01   2.329434e+01   3.172577e+01
# 75%       6.300000e+00       2.777500e+01   2.424304e+01   3.282538e+01
# max       3.060000e+02       3.300497e+01   2.959398e+01   3.973790e+01

# %%
data.columns
# Out:
# Index(['time', 'wmo_id', 'name', 'latitude', 'longitude', 'province',
#        'regency', 'elevation', 'RAINFALL_24H_MM', 'TEMPERATURE_AVG_C',
#        'TEMP_24H_TN_C', 'TEMP_24H_TX_C', 'TEMPERATURE_AVG_C_UP',
#        'TEMPERATURE_AVG_C_LOW', 'TEMPERATURE_AVG_C_QC_METHOD',
#        'TEMPERATURE_AVG_C_AVAILABLE', 'TEMP_24H_TN_C_UP', 'TEMP_24H_TN_C_LOW',
#        'TEMP_24H_TN_C_QC_METHOD', 'TEMP_24H_TN_C_AVAILABLE',
#        'TEMP_24H_TX_C_UP', 'TEMP_24H_TX_C_LOW', 'TEMP_24H_TX_C_QC_METHOD',
#        'TEMP_24H_TX_C_AVAILABLE', 'RAINFALL_24H_MM_UP', 'RAINFALL_24H_MM_LOW',
#        'RAINFALL_24H_MM_QC_METHOD', 'RAINFALL_24H_MM_AVAILABLE',
#        'PARAM_TEMPERATURE_AVAILABLE', 'PARAM_RAINFALL_AVAILABLE',
#        'PARAM_COUNT_AVAILABLE'],
#       dtype='object')
